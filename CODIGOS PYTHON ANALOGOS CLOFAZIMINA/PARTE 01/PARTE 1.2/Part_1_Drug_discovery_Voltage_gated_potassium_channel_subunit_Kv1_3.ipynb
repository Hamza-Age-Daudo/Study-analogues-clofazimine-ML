# %% [markdown]
# italicized text:## **UNIVERSIDADE LÚRIO**
#
#
# STUDENT: Hamza Age Daudo
#
# PROJECT: VIRTUAL SCREENING THROUGH QSAR-3D ANALYSIS OF POTENTIAL AGENTS USED IN THE FIGHT AGAINST LEPROSY - CLOFAZIMINE ANALOGUES.

# %% [markdown]
# INSTALLATIONS AND IMPORTS:
#
# This section should be executed every time this Notebook is reopened.

# %% [markdown]
# \1.1. Performing the necessary installations/uninstallations:

# %%
# !pip install fastapi kaleido python-multipart uvicorn
# !pip install chembl_webresource_client
# Out:
# Collecting fastapi
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Collecting python-multipart
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi) (2.10.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (4.12.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.27.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.42.0,>=0.40.0->fastapi) (3.7.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (1.2.2)
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 6.6 MB/s eta 0:00:00
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.5 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 2.6 MB/s eta 0:00:00
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: kaleido, uvicorn, python-multipart, starlette, fastapi
# Successfully installed fastapi-0.115.6 kaleido-0.2.1 python-multipart-0.0.20 starlette-0.41.3 uvicorn-0.34.0
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.12.14)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.3.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.17.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.2 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.2 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.2 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.2 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %% [markdown]
# 1.2. Importing necessary libraries:

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# PART 2:
# DATASET SELECTION:
#
# The chosen database is ChEMBL (https://www.ebi.ac.uk/chembl/). It is a database of bioactive, drug-like small molecules, containing 2D structures, calculated properties (e.g., logP, molecular weight, Lipinski parameters, etc.), and abstracted bioactivities (e.g., binding constants, pharmacology, and ADMET data). The data are summarized and curated from primary scientific literature, covering a significant portion of structure-activity relationships (SAR) and modern drug discovery.

# %% [markdown]
# 2.1 Searching for datasets targeting: "CHEMBL4633"

# %%
alvo = new_client.target
pesquisa_alvo = alvo.search('CHEMBL4633')
ds = pd.DataFrame.from_dict(pesquisa_alvo)
ds
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Homo sapiens
#
#                                        pref_name  score  species_group_flag  \
# 0  Voltage-gated potassium channel subunit Kv1.3   14.0               False
# 1                Voltage-gated potassium channel    2.0               False
#
#   target_chembl_id                                  target_components  \
# 0       CHEMBL4633  [{'accession': 'P22001', 'component_descriptio...
# 1    CHEMBL2362996  [{'accession': 'P51787', 'component_descriptio...
#
#       target_type  tax_id
# 0  SINGLE PROTEIN    9606
# 1  PROTEIN FAMILY    9606

# %% [markdown]
# 2.2 Searching for a specific target within the dataset:

# %%
# Defining the target to be searched:
alvo = "Voltage-gated potassium channel"

# Checking if any element in pref_name contains this target:
contains_alvo = ds['pref_name'].str.contains(alvo)

# Obtaining the indices of the rows with the defined target:
indices_com_alvo = ds[contains_alvo].index.tolist()

if contains_alvo.any():
    print(f"Pelo menos um elemento contém o termo: {alvo}")
    print(f"Índices das linhas com o termo '{alvo}': {indices_com_alvo}")
else:
    print(f"Nenhum elemento contém o termo: {alvo}")
# Out:
# Pelo menos um elemento contém o termo: Voltage-gated potassium channel
# Índices das linhas com o termo 'Voltage-gated potassium channel': [0, 1]

# %% [markdown]
# 2.3 Converting IC50 values to a standard concentration unit (Nanomolar - nM) and generating a single dataframe:
#
# In order to expand access to bioactivity data, a unit conversion system has been applied to transfer values in M, µM, mM to a standard nM unit.
#
# Note: For bioassays using common concentration units (m/v), such as µg/mL, the molar mass of each compound would be required to make this conversion feasible.

# %%
# prompt: select rows from df['target_chembl_id'] if in this list: 'CHEMBL612893','CHEMBL3797017','CHEMBL612644'

ensaios = ds[ds['target_chembl_id'].isin(["CHEMBL4633"])]
ensaios
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
#
#                                        pref_name  score  species_group_flag  \
# 0  Voltage-gated potassium channel subunit Kv1.3   14.0               False
#
#   target_chembl_id                                  target_components  \
# 0       CHEMBL4633  [{'accession': 'P22001', 'component_descriptio...
#
#       target_type  tax_id
# 0  SINGLE PROTEIN    9606

# %%
indices_com_ensaio = ensaios.index
indices_com_ensaio
# Out:
# Index([0], dtype='int64')

# %%
# Creating a list to store individual DataFrames (Required only during the first execution!):

dfs = []


# Iterating over the different indices:

for i in indices_com_ensaio :

    df_nM_i = []

    df_uM_i = []

    df_mM_i = []

    df_M_i = []

    ds_selecionado_i = ds.target_chembl_id[i]


    # Filtering bioactive compounds with IC50 data in nM units for each index:

    atividade = new_client.activity

    resultado_nM = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="nM")



    # Filtering bioactive compounds with IC50 data in µM units for each index:

    resultado_uM = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="uM")


    # Filtering bioactive compounds with IC50 data in mM units for each index:

    resultado_mM = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="mM")



    # Filtering bioactive compounds with IC50 data in M (molar) units for each index:

    resultado_M = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="M")


    # Creating a DataFrame for each unit:

    df_nM_i = pd.DataFrame.from_dict(resultado_nM)

    df_uM_i = pd.DataFrame.from_dict(resultado_uM)

    df_mM_i = pd.DataFrame.from_dict(resultado_mM)

    df_M_i = pd.DataFrame.from_dict(resultado_M)




    # Converting each DataFrame to a standard unit (Molar - M):

    if not df_nM_i.empty and 'value' in df_nM_i:

        df_nM_i['value'] = df_nM_i['value'].astype(float)

        df_nM_i['value'] *= 1e-9

    else:

        pass




    if not df_uM_i.empty and 'value' in df_uM_i:

        df_uM_i['value'] = df_uM_i['value'].astype(float)

        df_uM_i['value'] *= 1e-6

    else:

        pass




    if not df_mM_i.empty and 'value' in df_mM_i:

        df_mM_i['value'] = df_mM_i['value'].astype(float)

        df_mM_i['value'] *= 1e-3

    else:

        pass




    if not df_M_i.empty and 'value' in df_M_i:

        df_M_i['value'] = df_M_i['value'].astype(float)

    else:

        pass




    # Adding the DataFrames to the list:

    dfs.append(df_nM_i)

    dfs.append(df_uM_i)

    dfs.append(df_mM_i)

    dfs.append(df_M_i)





# Concatenating the individual DataFrames into a single DataFrame:

df_assays = pd.concat(dfs, ignore_index=True)

df_assays['units'] = 'M'




# Displaying the final DataFrame:

display(df_assays)
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 453  {'action_type': 'BLOCKER', 'description': 'Neg...             None
# 454  {'action_type': 'BLOCKER', 'description': 'Neg...             None
# 455  {'action_type': 'BLOCKER', 'description': 'Neg...             None
# 456  {'action_type': 'BLOCKER', 'description': 'Neg...             None
# 457  {'action_type': 'BLOCKER', 'description': 'Neg...             None
#
#      activity_id activity_properties assay_chembl_id  \
# 0         306427                  []    CHEMBL821183
# 1         475295                  []    CHEMBL750215
# 2         476425                  []    CHEMBL750215
# 3         477539                  []    CHEMBL750215
# 4         478943                  []    CHEMBL750215
# ..           ...                 ...             ...
# 453     24753720                  []   CHEMBL5121923
# 454     24753721                  []   CHEMBL5121923
# 455     24753722                  []   CHEMBL5121923
# 456     24753723                  []   CHEMBL5121923
# 457     25659736                  []   CHEMBL5373259
#
#                                      assay_description assay_type  \
# 0    Inhibition of voltage-gated potassium channel ...          B
# 1    Concentration inhibiting [125I]ChTX (charybdot...          B
# 2    Concentration inhibiting [125I]ChTX (charybdot...          B
# 3    Concentration inhibiting [125I]ChTX (charybdot...          B
# 4    Concentration inhibiting [125I]ChTX (charybdot...          B
# ..                                                 ...        ...
# 453  Inhibition of human Kv1.3 expressed in HEK293 ...          B
# 454  Inhibition of human Kv1.3 expressed in HEK293 ...          B
# 455  Inhibition of human Kv1.3 expressed in HEK293 ...          B
# 456  Inhibition of human Kv1.3 expressed in HEK293 ...          B
# 457  Inhibition of Kv1.3 (unknown origin) expressed...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                      None                   None  BAO_0000190  ...
# 1                      None                   None  BAO_0000190  ...
# 2                      None                   None  BAO_0000190  ...
# 3                      None                   None  BAO_0000190  ...
# 4                      None                   None  BAO_0000190  ...
# ..                      ...                    ...          ...  ...
# 453                    None                   None  BAO_0000190  ...
# 454                    None                   None  BAO_0000190  ...
# 455                    None                   None  BAO_0000190  ...
# 456                    None                   None  BAO_0000190  ...
# 457                    None                   None  BAO_0000190  ...
#
#     target_organism                               target_pref_name  \
# 0      Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 1      Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 2      Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 3      Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 4      Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# ..              ...                                            ...
# 453    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 454    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 455    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 456    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 457    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
#
#     target_tax_id text_value  toid  type units    uo_units upper_value  \
# 0            9606       None  None  IC50     M  UO_0000065        None
# 1            9606       None  None  IC50     M  UO_0000065        None
# 2            9606       None  None  IC50     M  UO_0000065        None
# 3            9606       None  None  IC50     M  UO_0000065        None
# 4            9606       None  None  IC50     M  UO_0000065        None
# ..            ...        ...   ...   ...   ...         ...         ...
# 453          9606       None  None  IC50     M  UO_0000065        None
# 454          9606       None  None  IC50     M  UO_0000065        None
# 455          9606       None  None  IC50     M  UO_0000065        None
# 456          9606       None  None  IC50     M  UO_0000065        None
# 457          9606       None  None  IC50     M  UO_0000065        None
#
#             value
# 0    8.600000e-08
# 1    2.400000e-07
# 2    4.710000e-07
# 3    5.000000e-06
# 4    1.000000e-05
# ..            ...
# 453  6.500000e-06
# 454  9.000000e-07
# 455  9.000000e-07
# 456  3.190000e-05
# 457  4.300000e-06
#
# [458 rows x 46 columns]

# %%
df_assays["value"].isnull().sum()
# Out:
# 0

# %%
# Assuming your DataFrame is df_assays:
df_assays.dropna(subset=['value'], inplace=True)

# %%
df_assays
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 453  {'action_type': 'BLOCKER', 'description': 'Neg...             None
# 454  {'action_type': 'BLOCKER', 'description': 'Neg...             None
# 455  {'action_type': 'BLOCKER', 'description': 'Neg...             None
# 456  {'action_type': 'BLOCKER', 'description': 'Neg...             None
# 457  {'action_type': 'BLOCKER', 'description': 'Neg...             None
#
#      activity_id activity_properties assay_chembl_id  \
# 0         306427                  []    CHEMBL821183
# 1         475295                  []    CHEMBL750215
# 2         476425                  []    CHEMBL750215
# 3         477539                  []    CHEMBL750215
# 4         478943                  []    CHEMBL750215
# ..           ...                 ...             ...
# 453     24753720                  []   CHEMBL5121923
# 454     24753721                  []   CHEMBL5121923
# 455     24753722                  []   CHEMBL5121923
# 456     24753723                  []   CHEMBL5121923
# 457     25659736                  []   CHEMBL5373259
#
#                                      assay_description assay_type  \
# 0    Inhibition of voltage-gated potassium channel ...          B
# 1    Concentration inhibiting [125I]ChTX (charybdot...          B
# 2    Concentration inhibiting [125I]ChTX (charybdot...          B
# 3    Concentration inhibiting [125I]ChTX (charybdot...          B
# 4    Concentration inhibiting [125I]ChTX (charybdot...          B
# ..                                                 ...        ...
# 453  Inhibition of human Kv1.3 expressed in HEK293 ...          B
# 454  Inhibition of human Kv1.3 expressed in HEK293 ...          B
# 455  Inhibition of human Kv1.3 expressed in HEK293 ...          B
# 456  Inhibition of human Kv1.3 expressed in HEK293 ...          B
# 457  Inhibition of Kv1.3 (unknown origin) expressed...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                      None                   None  BAO_0000190  ...
# 1                      None                   None  BAO_0000190  ...
# 2                      None                   None  BAO_0000190  ...
# 3                      None                   None  BAO_0000190  ...
# 4                      None                   None  BAO_0000190  ...
# ..                      ...                    ...          ...  ...
# 453                    None                   None  BAO_0000190  ...
# 454                    None                   None  BAO_0000190  ...
# 455                    None                   None  BAO_0000190  ...
# 456                    None                   None  BAO_0000190  ...
# 457                    None                   None  BAO_0000190  ...
#
#     target_organism                               target_pref_name  \
# 0      Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 1      Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 2      Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 3      Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 4      Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# ..              ...                                            ...
# 453    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 454    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 455    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 456    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 457    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
#
#     target_tax_id text_value  toid  type units    uo_units upper_value  \
# 0            9606       None  None  IC50     M  UO_0000065        None
# 1            9606       None  None  IC50     M  UO_0000065        None
# 2            9606       None  None  IC50     M  UO_0000065        None
# 3            9606       None  None  IC50     M  UO_0000065        None
# 4            9606       None  None  IC50     M  UO_0000065        None
# ..            ...        ...   ...   ...   ...         ...         ...
# 453          9606       None  None  IC50     M  UO_0000065        None
# 454          9606       None  None  IC50     M  UO_0000065        None
# 455          9606       None  None  IC50     M  UO_0000065        None
# 456          9606       None  None  IC50     M  UO_0000065        None
# 457          9606       None  None  IC50     M  UO_0000065        None
#
#             value
# 0    8.600000e-08
# 1    2.400000e-07
# 2    4.710000e-07
# 3    5.000000e-06
# 4    1.000000e-05
# ..            ...
# 453  6.500000e-06
# 454  9.000000e-07
# 455  9.000000e-07
# 456  3.190000e-05
# 457  4.300000e-06
#
# [458 rows x 46 columns]

# %%
# Calculate the percentage of each category in the 'assay_type' column
assay_type_percentages = df_assays['assay_type'].value_counts(normalize=True) * 100
print(assay_type_percentages)
# Out:
# assay_type
# B    60.043668
# F    39.956332
# Name: proportion, dtype: float64

# %%
# Filtering the DataFrame to include only rows where 'assay_type' is 'F'

df_assays_f_only = df_assays[df_assays['assay_type'] == 'F']
df_assays_f_only
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 7          None             None       482633                  []
# 9          None             None       482635                  []
# 12         None             None       486204                  []
# 15         None             None       489711                  []
# 17         None             None       490896                  []
# ..          ...              ...          ...                 ...
# 244        None             None       550013                  []
# 245        None             None       550014                  []
# 246        None             None       551242                  []
# 250        None             None      1421374                  []
# 275        None             None      2619840                  []
#
#     assay_chembl_id                                  assay_description  \
# 7      CHEMBL750216  Inhibition of outward potassium currents (IKn)...
# 9      CHEMBL750216  Inhibition of outward potassium currents (IKn)...
# 12     CHEMBL750216  Inhibition of outward potassium currents (IKn)...
# 15     CHEMBL750216  Inhibition of outward potassium currents (IKn)...
# 17     CHEMBL750216  Inhibition of outward potassium currents (IKn)...
# ..              ...                                                ...
# 244    CHEMBL705534  Inhibition of Kv1.3 ion channel. Measured in t...
# 245    CHEMBL705534  Inhibition of Kv1.3 ion channel. Measured in t...
# 246    CHEMBL705534  Inhibition of Kv1.3 ion channel. Measured in t...
# 250    CHEMBL834727  Inhibitory activity against voltage-gated pota...
# 275   CHEMBL1014288  Antagonist activity at voltage-gated Kv1.3 pot...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 7            F                    None                   None  BAO_0000190
# 9            F                    None                   None  BAO_0000190
# 12           F                    None                   None  BAO_0000190
# 15           F                    None                   None  BAO_0000190
# 17           F                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 244          F                    None                   None  BAO_0000190
# 245          F                    None                   None  BAO_0000190
# 246          F                    None                   None  BAO_0000190
# 250          F                    None                   None  BAO_0000190
# 275          F                    None                   None  BAO_0000190
#
#      ... target_organism                               target_pref_name  \
# 7    ...    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 9    ...    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 12   ...    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 15   ...    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 17   ...    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# ..   ...             ...                                            ...
# 244  ...    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 245  ...    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 246  ...    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 250  ...    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
# 275  ...    Homo sapiens  Voltage-gated potassium channel subunit Kv1.3
#
#     target_tax_id text_value  toid  type units    uo_units upper_value  \
# 7            9606       None  None  IC50     M  UO_0000065        None
# 9            9606       None  None  IC50     M  UO_0000065        None
# 12           9606       None  None  IC50     M  UO_0000065        None
# 15           9606       None  None  IC50     M  UO_0000065        None
# 17           9606       None  None  IC50     M  UO_0000065        None
# ..            ...        ...   ...   ...   ...         ...         ...
# 244          9606       None  None  IC50     M  UO_0000065        None
# 245          9606       None  None  IC50     M  UO_0000065        None
# 246          9606       None  None  IC50     M  UO_0000065        None
# 250          9606       None  None  IC50     M  UO_0000065        None
# 275          9606       None  None  IC50     M  UO_0000065        None
#
#             value
# 7    3.160000e-06
# 9    1.053000e-06
# 12   2.310000e-07
# 15   2.160000e-07
# 17   4.340000e-07
# ..            ...
# 244  1.000000e-05
# 245  3.000000e-05
# 246  3.000000e-05
# 250  5.600000e-06
# 275  3.900000e-06
#
# [183 rows x 46 columns]

# %%
## Assigning the class of compounds: active if IC50 < 1000 nM, inactive if IC50 > 10000 nM, and intermediate if IC50 is between 1000 nM and 100000 nM.
## The variable of interest is always "standard_value".

bioactivity_class = []
for i in df_assays_f_only.standard_value:
    if float(i) >= 10000:
        bioactivity_class.append("Inactive")
    elif float(i) < 1000:
        bioactivity_class.append("Active")
    else:
        bioactivity_class.append("Intermediate")

# %%
# Viewing the bioactive compounds
df_assays_f_only.molecule_chembl_id
# Out:
# 7       CHEMBL55791
# 9       CHEMBL56173
# 12      CHEMBL53676
# 15     CHEMBL298622
# 17      CHEMBL56589
#            ...
# 244    CHEMBL278501
# 245    CHEMBL265334
# 246     CHEMBL16428
# 250    CHEMBL360583
# 275    CHEMBL516932
# Name: molecule_chembl_id, Length: 183, dtype: object

# %%
## 7.1. Iterating through the bioactive compounds:
mol_cid = []
for i in df_assays_f_only.molecule_chembl_id:
    mol_cid.append(i)

# %%
# Printing the variable mol_cid:
mol_cid
# Out:
# ['CHEMBL55791',
#  'CHEMBL56173',
#  'CHEMBL53676',
#  'CHEMBL298622',
#  'CHEMBL56589',
#  'CHEMBL54934',
#  'CHEMBL293719',
#  'CHEMBL299668',
#  'CHEMBL56590',
#  'CHEMBL53841',
#  'CHEMBL59482',
#  'CHEMBL293083',
#  'CHEMBL55202',
#  'CHEMBL298608',
#  'CHEMBL416313',
#  'CHEMBL293721',
#  'CHEMBL54846',
#  'CHEMBL59308',
#  'CHEMBL56261',
#  'CHEMBL274227',
#  'CHEMBL279370',
#  'CHEMBL16308',
#  'CHEMBL278660',
#  'CHEMBL278660',
#  'CHEMBL277598',
#  'CHEMBL277598',
#  'CHEMBL275836',
#  'CHEMBL16806',
#  'CHEMBL16806',
#  'CHEMBL16917',
#  'CHEMBL16792',
#  'CHEMBL279358',
#  'CHEMBL16449',
#  'CHEMBL16432',
#  'CHEMBL16432',
#  'CHEMBL16446',
#  'CHEMBL16446',
#  'CHEMBL16848',
#  'CHEMBL16848',
#  'CHEMBL277952',
#  'CHEMBL276543',
#  'CHEMBL280102',
#  'CHEMBL280102',
#  'CHEMBL16706',
#  'CHEMBL280052',
#  'CHEMBL16110',
#  'CHEMBL16450',
#  'CHEMBL16581',
#  'CHEMBL16581',
#  'CHEMBL16804',
#  'CHEMBL16804',
#  'CHEMBL429234',
#  'CHEMBL441507',
#  'CHEMBL16945',
#  'CHEMBL16945',
#  'CHEMBL277287',
#  'CHEMBL277287',
#  'CHEMBL280079',
#  'CHEMBL417995',
#  'CHEMBL417995',
#  'CHEMBL277064',
#  'CHEMBL277064',
#  'CHEMBL279529',
#  'CHEMBL277812',
#  'CHEMBL277812',
#  'CHEMBL416538',
#  'CHEMBL16702',
#  'CHEMBL16877',
#  'CHEMBL16877',
#  'CHEMBL16683',
#  'CHEMBL16683',
#  'CHEMBL16652',
#  'CHEMBL16983',
#  'CHEMBL16983',
#  'CHEMBL278269',
#  'CHEMBL16609',
#  'CHEMBL16609',
#  'CHEMBL278945',
#  'CHEMBL278945',
#  'CHEMBL16255',
#  'CHEMBL16255',
#  'CHEMBL16890',
#  'CHEMBL16311',
#  'CHEMBL16311',
#  'CHEMBL279606',
#  'CHEMBL16381',
#  'CHEMBL276523',
#  'CHEMBL16844',
#  'CHEMBL16844',
#  'CHEMBL16468',
#  'CHEMBL16468',
#  'CHEMBL276059',
#  'CHEMBL276059',
#  'CHEMBL275152',
#  'CHEMBL274017',
#  'CHEMBL16882',
#  'CHEMBL273351',
#  'CHEMBL278734',
#  'CHEMBL278734',
#  'CHEMBL16766',
#  'CHEMBL16766',
#  'CHEMBL16961',
#  'CHEMBL276591',
#  'CHEMBL278213',
#  'CHEMBL278213',
#  'CHEMBL16287',
#  'CHEMBL16780',
#  'CHEMBL362198',
#  'CHEMBL362198',
#  'CHEMBL434526',
#  'CHEMBL362199',
#  'CHEMBL361188',
#  'CHEMBL362068',
#  'CHEMBL368019',
#  'CHEMBL368429',
#  'CHEMBL369340',
#  'CHEMBL366929',
#  'CHEMBL362445',
#  'CHEMBL362445',
#  'CHEMBL362446',
#  'CHEMBL359622',
#  'CHEMBL368907',
#  'CHEMBL368907',
#  'CHEMBL178867',
#  'CHEMBL178867',
#  'CHEMBL359497',
#  'CHEMBL359497',
#  'CHEMBL361777',
#  'CHEMBL361777',
#  'CHEMBL425156',
#  'CHEMBL435093',
#  'CHEMBL435093',
#  'CHEMBL425865',
#  'CHEMBL425865',
#  'CHEMBL367603',
#  'CHEMBL367603',
#  'CHEMBL361828',
#  'CHEMBL362467',
#  'CHEMBL180972',
#  'CHEMBL180972',
#  'CHEMBL182080',
#  'CHEMBL182080',
#  'CHEMBL180665',
#  'CHEMBL180665',
#  'CHEMBL178086',
#  'CHEMBL178086',
#  'CHEMBL361810',
#  'CHEMBL361810',
#  'CHEMBL178146',
#  'CHEMBL178146',
#  'CHEMBL362608',
#  'CHEMBL362608',
#  'CHEMBL360276',
#  'CHEMBL360276',
#  'CHEMBL368435',
#  'CHEMBL368435',
#  'CHEMBL368210',
#  'CHEMBL176278',
#  'CHEMBL176278',
#  'CHEMBL435336',
#  'CHEMBL435336',
#  'CHEMBL366546',
#  'CHEMBL366546',
#  'CHEMBL359659',
#  'CHEMBL359659',
#  'CHEMBL362825',
#  'CHEMBL360060',
#  'CHEMBL360060',
#  'CHEMBL360061',
#  'CHEMBL278971',
#  'CHEMBL17027',
#  'CHEMBL278915',
#  'CHEMBL16518',
#  'CHEMBL16464',
#  'CHEMBL16746',
#  'CHEMBL16512',
#  'CHEMBL422393',
#  'CHEMBL279337',
#  'CHEMBL278501',
#  'CHEMBL265334',
#  'CHEMBL16428',
#  'CHEMBL360583',
#  'CHEMBL516932']

# %%
## 7.2. Iterating over canonical SMILES into a list.
canonical_smiles = []
for i in df_assays.canonical_smiles:
    canonical_smiles.append(i)

# %%
## 7.3. Iterating over standard_value into a list.
standard_value = []
for i in df_assays.standard_value:
    standard_value.append(i)

# %%
## 7.4. Combining the four variables into the same DataFrame.
dados_tupla = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( dados_tupla,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL55791  C=C(C)O[C@H]1[C@@H](OC(C)=O)[C@H]2[C@@](C)(CC[...
# 1          CHEMBL56173  CCCCCCNc1cc[n+](-c2ccccc2)c2c(-c3ccccc3)cc(OC)...
# 2          CHEMBL53676            CCCC/N=c1\ccn(CCCc2ccccc2)c2cc(Cl)ccc12
# 3         CHEMBL298622                   CCCCCCOc1ccc(Cc2ccccc2)c2ccccc12
# 4          CHEMBL56589        O=C(O)CC/N=c1\ccn(Cc2ccccc2Cl)c2cc(Cl)ccc12
# ..                 ...                                                ...
# 178       CHEMBL278501  COc1ccccc1CCC1(O)C(C)=C[C@@H](OC(C)=O)[C@@]2(C...
# 179       CHEMBL265334  CCOc1ccccc1CCC1(O)C(C)=C[C@@H](OC(C)=O)[C@@]2(...
# 180        CHEMBL16428  CCOc1ccccc1CCC1(O)C(C)=C[C@@H](OC(C)=O)[C@@]2(...
# 181       CHEMBL360583  COc1cccc(CCC2(O)C(C)=C[C@@H](OC(C)=O)[C@@]3(C)...
# 182       CHEMBL516932  COc1cccc(CCC2(O)C(C)=C[C@@H](OC(C)=O)[C@@]3(C)...
#
#     bioactivity_class standard_value
# 0        Intermediate           86.0
# 1        Intermediate          240.0
# 2              Active          471.0
# 3              Active         5000.0
# 4              Active        10000.0
# ..                ...            ...
# 178          Inactive          142.0
# 179          Inactive           34.0
# 180          Inactive           80.0
# 181      Intermediate           24.0
# 182      Intermediate         1314.0
#
# [183 rows x 4 columns]

# %%
# Saving the DataFrame to a CSV file.

df3.to_csv('Voltage-gated potassium channel subunit Kv1.3 F.csv', index=False)

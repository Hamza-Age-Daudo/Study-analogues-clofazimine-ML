# %% [markdown]
# STUDENT: Hamza Age Daudo
#
# PROJECT: VIRTUAL SCREENING THROUGH QSAR-3D ANALYSIS OF POTENTIAL AGENTS USED IN THE FIGHT AGAINST LEPROSY - CLOFAZIMINE ANALOGUES.

# %% [markdown]
# INSTALLATIONS AND IMPORTS:
#
# This section should be executed every time this Notebook is reopened.

# %% [markdown]
# \1.1. Performing the necessary installations/uninstallations:

# %%
# !pip install fastapi kaleido python-multipart uvicorn
# !pip install chembl_webresource_client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fastapi in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.111.0)
# Requirement already satisfied: kaleido in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.2.1)
# Requirement already satisfied: python-multipart in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.0.9)
# Requirement already satisfied: uvicorn in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.30.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi) (0.37.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi) (3.1.4)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi) (5.10.0)
# Requirement already satisfied: orjson>=3.2.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi) (3.10.6)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi) (2.2.0)
# Requirement already satisfied: click>=7.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from email_validator>=2.0.0->fastapi) (2.6.1)
# Requirement already satisfied: idna>=2.0.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from email_validator>=2.0.0->fastapi) (3.7)
# Requirement already satisfied: typer>=0.12.3 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from fastapi-cli>=0.0.2->fastapi) (0.12.3)
# Requirement already satisfied: anyio in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx>=0.23.0->fastapi) (4.4.0)
# Requirement already satisfied: certifi in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx>=0.23.0->fastapi) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx>=0.23.0->fastapi) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx>=0.23.0->fastapi) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jinja2>=2.11.2->fastapi) (2.1.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.20.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (1.0.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (6.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from uvicorn[standard]>=0.12.0->fastapi) (12.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (0.1.2)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: chembl_webresource_client in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.10.9)
# Requirement already satisfied: urllib3 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from chembl_webresource_client) (2.2.2)
# Requirement already satisfied: requests>=2.18.4 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.18.4->chembl_webresource_client) (2024.7.4)
# Requirement already satisfied: attrs>=21.2 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests-cache~=1.2->chembl_webresource_client) (4.2.2)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in c:\users\dell\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# 1.2. Importing necessary libraries:

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 from chembl_webresource_client.new_client import new_client
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## **PART 2:**
#
# DATASET SELECTION:
#
# The chosen database is ChEMBL (https://www.ebi.ac.uk/chembl/). It is a database of bioactive, drug-like small molecules, containing 2D structures, calculated properties (e.g., logP, molecular weight, Lipinski parameters, etc.), and abstracted bioactivities (e.g., binding constants, pharmacology, and ADMET data). The data are summarized and curated from primary scientific literature, covering a significant portion of structure-activity relationships (SAR) and modern drug discovery.

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# 2.1 Searching for datasets targeting: "CHEMBL235"

# %%
alvo = new_client.target
pesquisa_alvo = alvo.search('CHEMBL235')
ds = pd.DataFrame.from_dict(pesquisa_alvo)
ds
# Out:
#                                     cross_references      organism  \
# 0  [{'xref_id': 'P37231', 'xref_name': None, 'xre...  Homo sapiens
# 1                                                 []  Homo sapiens
# 2                                                 []  Homo sapiens
# 3                                                 []  Homo sapiens
# 4                                                 []  Homo sapiens
# 5                                                 []  Homo sapiens
# 6                                                 []  Homo sapiens
# 7                                                 []  Homo sapiens
# 8                                                 []  Homo sapiens
#
#                                            pref_name  score  \
# 0   Peroxisome proliferator-activated receptor gamma   12.0
# 1  Peroxisome proliferator-activated receptor gam...    7.0
# 2  Peroxisome proliferator-activated receptor gam...    6.0
# 3  Peroxisome proliferator-activated receptor gam...    6.0
# 4  Peroxisome proliferator-activated receptor gam...    6.0
# 5                                   PPAR alpha/gamma    6.0
# 6                                   PPAR delta/gamma    6.0
# 7         Peroxisome proliferator-activated receptor    5.0
# 8                               RXR alpha/PPAR gamma    4.0
#
#    species_group_flag target_chembl_id  \
# 0               False        CHEMBL235
# 1               False    CHEMBL2095163
# 2               False    CHEMBL2095161
# 3               False    CHEMBL2095162
# 4               False    CHEMBL2096976
# 5               False    CHEMBL2111325
# 6               False    CHEMBL2111371
# 7               False    CHEMBL3559683
# 8               False    CHEMBL2111394
#
#                                    target_components  \
# 0  [{'accession': 'P37231', 'component_descriptio...
# 1  [{'accession': 'P37231', 'component_descriptio...
# 2  [{'accession': 'P37231', 'component_descriptio...
# 3  [{'accession': 'P37231', 'component_descriptio...
# 4  [{'accession': 'P37231', 'component_descriptio...
# 5  [{'accession': 'P37231', 'component_descriptio...
# 6  [{'accession': 'P37231', 'component_descriptio...
# 7  [{'accession': 'P37231', 'component_descriptio...
# 8  [{'accession': 'P37231', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN    9606
# 1  PROTEIN-PROTEIN INTERACTION    9606
# 2  PROTEIN-PROTEIN INTERACTION    9606
# 3  PROTEIN-PROTEIN INTERACTION    9606
# 4  PROTEIN-PROTEIN INTERACTION    9606
# 5            SELECTIVITY GROUP    9606
# 6            SELECTIVITY GROUP    9606
# 7               PROTEIN FAMILY    9606
# 8              PROTEIN COMPLEX    9606

# %% [markdown]
# 2.2 Searching for a specific target within the dataset:

# %%
# Defining the target to be searched:
alvo = "Peroxisome proliferator-activated receptor gamma"

# Checking if any element in pref_name contains this target:
contains_alvo = ds['pref_name'].str.contains(alvo)

# Obtaining the indices of the rows with the defined target:
indices_com_alvo = ds[contains_alvo].index.tolist()

if contains_alvo.any():
    print(f"Pelo menos um elemento contém o termo: {alvo}")
    print(f"Índices das linhas com o termo '{alvo}': {indices_com_alvo}")
else:
    print(f"Nenhum elemento contém o termo: {alvo}")
# Out:
# Pelo menos um elemento contém o termo: Peroxisome proliferator-activated receptor gamma
# Índices das linhas com o termo 'Peroxisome proliferator-activated receptor gamma': [0, 1, 2, 3, 4]

# %% [markdown]
# 2.3 Converting IC50 values to a standard concentration unit (Nanomolar - nM) and generating a single dataframe:
#
# In order to expand access to bioactivity data, a unit conversion system has been applied to transfer values in M, µM, mM to a standard nM unit.
#
# Note: For bioassays using common concentration units (m/v), such as µg/mL, the molar mass of each compound would be required to make this conversion feasible.

# %%
# prompt: select rows from df['target_chembl_id'] if in this list: 'CHEMBL612893','CHEMBL3797017','CHEMBL612644'

ensaios = ds[ds['target_chembl_id'].isin(["CHEMBL235"])]
ensaios
# Out:
#                                     cross_references      organism  \
# 0  [{'xref_id': 'P37231', 'xref_name': None, 'xre...  Homo sapiens
#
#                                           pref_name  score  \
# 0  Peroxisome proliferator-activated receptor gamma   12.0
#
#    species_group_flag target_chembl_id  \
# 0               False        CHEMBL235
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'P37231', 'component_descriptio...  SINGLE PROTEIN    9606

# %%
indices_com_ensaio = ensaios.index
indices_com_ensaio
# Out:
# Index([0], dtype='int64')

# %%
# Creating a list to store individual DataFrames (Required only during the first execution!):

dfs = []




# Iterating over the different indices:

for i in indices_com_ensaio :

    df_nM_i = []

    df_uM_i = []

    df_mM_i = []

    df_M_i = []

    ds_selecionado_i = ds.target_chembl_id[i]




    # Filtering bioactive compounds with IC50 data in nM units for each index:

    atividade = new_client.activity

    resultado_nM = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="nM")




    # Filtering bioactive compounds with IC50 data in µM units for each index:

    resultado_uM = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="uM")




    # Filtering bioactive compounds with IC50 data in mM units for each index:

    resultado_mM = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="mM")




    # Filtering bioactive compounds with IC50 data in M (molar) units for each index:

    resultado_M = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="M")



    # Creating a DataFrame for each unit:

    df_nM_i = pd.DataFrame.from_dict(resultado_nM)

    df_uM_i = pd.DataFrame.from_dict(resultado_uM)

    df_mM_i = pd.DataFrame.from_dict(resultado_mM)

    df_M_i = pd.DataFrame.from_dict(resultado_M)





    # Converting each DataFrame to a standard unit (Molar - M):

    if not df_nM_i.empty and 'value' in df_nM_i:

        df_nM_i['value'] = df_nM_i['value'].astype(float)

        df_nM_i['value'] *= 1e-9

    else:

        pass




    if not df_uM_i.empty and 'value' in df_uM_i:

        df_uM_i['value'] = df_uM_i['value'].astype(float)

        df_uM_i['value'] *= 1e-6

    else:

        pass




    if not df_mM_i.empty and 'value' in df_mM_i:

        df_mM_i['value'] = df_mM_i['value'].astype(float)

        df_mM_i['value'] *= 1e-3

    else:

        pass




    if not df_M_i.empty and 'value' in df_M_i:

        df_M_i['value'] = df_M_i['value'].astype(float)

    else:

        pass



    # Adding the DataFrames to the list:

    dfs.append(df_nM_i)

    dfs.append(df_uM_i)

    dfs.append(df_mM_i)

    dfs.append(df_M_i)





# Concatenating the individual DataFrames into a single DataFrame:

df_assays = pd.concat(dfs, ignore_index=True)

df_assays['units'] = 'M'





# Displaying the final DataFrame:

display(df_assays)
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1905  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 1906  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 1907  {'action_type': 'ANTAGONIST', 'description': '...             None
# 1908  {'action_type': 'PARTIAL AGONIST', 'descriptio...             None
# 1909  {'action_type': 'AGONIST', 'description': 'Bin...             None
#
#       activity_id activity_properties assay_chembl_id  \
# 0          184830                  []    CHEMBL760384
# 1          186297                  []    CHEMBL760384
# 2          189892                  []    CHEMBL760384
# 3          191184                  []    CHEMBL760384
# 4          194645                  []    CHEMBL760384
# ...           ...                 ...             ...
# 1905     25031279                  []   CHEMBL5241789
# 1906     25031283                  []   CHEMBL5241789
# 1907     25031302                  []   CHEMBL5241798
# 1908     25092762                  []   CHEMBL5258849
# 1909     25110727                  []   CHEMBL5265012
#
#                                       assay_description assay_type  \
# 0     Displacement of PPARgamma agonist from human P...          F
# 1     Displacement of PPARgamma agonist from human P...          F
# 2     Displacement of PPARgamma agonist from human P...          F
# 3     Displacement of PPARgamma agonist from human P...          F
# 4     Displacement of PPARgamma agonist from human P...          F
# ...                                                 ...        ...
# 1905     Agonist activity at PPARgamma (unknown origin)          B
# 1906     Agonist activity at PPARgamma (unknown origin)          B
# 1907  Antagonist activity at PPARgamma (unknown origin)          B
# 1908  Partial agonist activity at PPARgamma (unknown...          B
# 1909     Binding affinity to PPARgamma (unknown origin)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000190  ...
# 1                       None                   None  BAO_0000190  ...
# 2                       None                   None  BAO_0000190  ...
# 3                       None                   None  BAO_0000190  ...
# 4                       None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 1905                    None                   None  BAO_0000190  ...
# 1906                    None                   None  BAO_0000190  ...
# 1907                    None                   None  BAO_0000190  ...
# 1908                    None                   None  BAO_0000190  ...
# 1909                    None                   None  BAO_0000190  ...
#
#      target_organism                                  target_pref_name  \
# 0       Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1       Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 2       Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 3       Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 4       Homo sapiens  Peroxisome proliferator-activated receptor gamma
# ...              ...                                               ...
# 1905    Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1906    Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1907    Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1908    Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1909    Homo sapiens  Peroxisome proliferator-activated receptor gamma
#
#      target_tax_id text_value  toid  type units    uo_units upper_value  \
# 0             9606       None  None  IC50     M  UO_0000065        None
# 1             9606       None  None  IC50     M  UO_0000065        None
# 2             9606       None  None  IC50     M  UO_0000065        None
# 3             9606       None  None  IC50     M  UO_0000065        None
# 4             9606       None  None  IC50     M  UO_0000065        None
# ...            ...        ...   ...   ...   ...         ...         ...
# 1905          9606       None  None  IC50     M  UO_0000065        None
# 1906          9606       None  None  IC50     M  UO_0000065        None
# 1907          9606       None  None  IC50     M  UO_0000065        None
# 1908          9606       None  None  IC50     M  UO_0000065        None
# 1909          9606       None  None  IC50     M  UO_0000065        None
#
#              value
# 0     1.400000e-08
# 1     1.800000e-08
# 2     1.280000e-07
# 3     1.500000e-08
# 4     1.000000e-08
# ...            ...
# 1905  2.310000e-05
# 1906  5.660000e-07
# 1907  3.500000e-06
# 1908  5.300000e-06
# 1909  1.800000e-08
#
# [1910 rows x 46 columns]

# %%
df_assays["value"].isnull().sum()
# Out:
# 18

# %%
# Assuming your DataFrame is df_assays:
df_assays.dropna(subset=['value'], inplace=True)

# %%
df_assays
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1905  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 1906  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 1907  {'action_type': 'ANTAGONIST', 'description': '...             None
# 1908  {'action_type': 'PARTIAL AGONIST', 'descriptio...             None
# 1909  {'action_type': 'AGONIST', 'description': 'Bin...             None
#
#       activity_id activity_properties assay_chembl_id  \
# 0          184830                  []    CHEMBL760384
# 1          186297                  []    CHEMBL760384
# 2          189892                  []    CHEMBL760384
# 3          191184                  []    CHEMBL760384
# 4          194645                  []    CHEMBL760384
# ...           ...                 ...             ...
# 1905     25031279                  []   CHEMBL5241789
# 1906     25031283                  []   CHEMBL5241789
# 1907     25031302                  []   CHEMBL5241798
# 1908     25092762                  []   CHEMBL5258849
# 1909     25110727                  []   CHEMBL5265012
#
#                                       assay_description assay_type  \
# 0     Displacement of PPARgamma agonist from human P...          F
# 1     Displacement of PPARgamma agonist from human P...          F
# 2     Displacement of PPARgamma agonist from human P...          F
# 3     Displacement of PPARgamma agonist from human P...          F
# 4     Displacement of PPARgamma agonist from human P...          F
# ...                                                 ...        ...
# 1905     Agonist activity at PPARgamma (unknown origin)          B
# 1906     Agonist activity at PPARgamma (unknown origin)          B
# 1907  Antagonist activity at PPARgamma (unknown origin)          B
# 1908  Partial agonist activity at PPARgamma (unknown...          B
# 1909     Binding affinity to PPARgamma (unknown origin)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000190  ...
# 1                       None                   None  BAO_0000190  ...
# 2                       None                   None  BAO_0000190  ...
# 3                       None                   None  BAO_0000190  ...
# 4                       None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 1905                    None                   None  BAO_0000190  ...
# 1906                    None                   None  BAO_0000190  ...
# 1907                    None                   None  BAO_0000190  ...
# 1908                    None                   None  BAO_0000190  ...
# 1909                    None                   None  BAO_0000190  ...
#
#      target_organism                                  target_pref_name  \
# 0       Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1       Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 2       Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 3       Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 4       Homo sapiens  Peroxisome proliferator-activated receptor gamma
# ...              ...                                               ...
# 1905    Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1906    Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1907    Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1908    Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1909    Homo sapiens  Peroxisome proliferator-activated receptor gamma
#
#      target_tax_id text_value  toid  type units    uo_units upper_value  \
# 0             9606       None  None  IC50     M  UO_0000065        None
# 1             9606       None  None  IC50     M  UO_0000065        None
# 2             9606       None  None  IC50     M  UO_0000065        None
# 3             9606       None  None  IC50     M  UO_0000065        None
# 4             9606       None  None  IC50     M  UO_0000065        None
# ...            ...        ...   ...   ...   ...         ...         ...
# 1905          9606       None  None  IC50     M  UO_0000065        None
# 1906          9606       None  None  IC50     M  UO_0000065        None
# 1907          9606       None  None  IC50     M  UO_0000065        None
# 1908          9606       None  None  IC50     M  UO_0000065        None
# 1909          9606       None  None  IC50     M  UO_0000065        None
#
#              value
# 0     1.400000e-08
# 1     1.800000e-08
# 2     1.280000e-07
# 3     1.500000e-08
# 4     1.000000e-08
# ...            ...
# 1905  2.310000e-05
# 1906  5.660000e-07
# 1907  3.500000e-06
# 1908  5.300000e-06
# 1909  1.800000e-08
#
# [1892 rows x 46 columns]

# %%
# Calculate the percentage of each category in the 'assay_type' column
assay_type_percentages = df_assays['assay_type'].value_counts(normalize=True) * 100
print(assay_type_percentages)
# Out:
# assay_type
# B    90.591966
# F     8.350951
# A     1.057082
# Name: proportion, dtype: float64

# %%
# Filtering the DataFrame to include only rows where 'assay_type' is 'F'

df_assays_f_only = df_assays[df_assays['assay_type'] == 'B']
df_assays_f_only
# Out:
#                                             action_type activity_comment  \
# 14                                                 None             None
# 15                                                 None             None
# 16                                                 None             None
# 17                                                 None             None
# 18                                                 None             None
# ...                                                 ...              ...
# 1905  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 1906  {'action_type': 'AGONIST', 'description': 'Bin...             None
# 1907  {'action_type': 'ANTAGONIST', 'description': '...             None
# 1908  {'action_type': 'PARTIAL AGONIST', 'descriptio...             None
# 1909  {'action_type': 'AGONIST', 'description': 'Bin...             None
#
#       activity_id activity_properties assay_chembl_id  \
# 14         541035                  []    CHEMBL759456
# 15         907914                  []    CHEMBL759455
# 16         924270                  []    CHEMBL759455
# 17         927129                  []    CHEMBL759455
# 18         927135                  []    CHEMBL759455
# ...           ...                 ...             ...
# 1905     25031279                  []   CHEMBL5241789
# 1906     25031283                  []   CHEMBL5241789
# 1907     25031302                  []   CHEMBL5241798
# 1908     25092762                  []   CHEMBL5258849
# 1909     25110727                  []   CHEMBL5265012
#
#                                       assay_description assay_type  \
# 14          Inhibitory concentration of the PPAR gamma)          B
# 15    Inhibitory activity of compound against the bi...          B
# 16    Inhibitory activity of compound against the bi...          B
# 17    Inhibitory activity of compound against the bi...          B
# 18    Inhibitory activity of compound against the bi...          B
# ...                                                 ...        ...
# 1905     Agonist activity at PPARgamma (unknown origin)          B
# 1906     Agonist activity at PPARgamma (unknown origin)          B
# 1907  Antagonist activity at PPARgamma (unknown origin)          B
# 1908  Partial agonist activity at PPARgamma (unknown...          B
# 1909     Binding affinity to PPARgamma (unknown origin)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 14                      None                   None  BAO_0000190  ...
# 15                      None                   None  BAO_0000190  ...
# 16                      None                   None  BAO_0000190  ...
# 17                      None                   None  BAO_0000190  ...
# 18                      None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 1905                    None                   None  BAO_0000190  ...
# 1906                    None                   None  BAO_0000190  ...
# 1907                    None                   None  BAO_0000190  ...
# 1908                    None                   None  BAO_0000190  ...
# 1909                    None                   None  BAO_0000190  ...
#
#      target_organism                                  target_pref_name  \
# 14      Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 15      Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 16      Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 17      Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 18      Homo sapiens  Peroxisome proliferator-activated receptor gamma
# ...              ...                                               ...
# 1905    Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1906    Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1907    Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1908    Homo sapiens  Peroxisome proliferator-activated receptor gamma
# 1909    Homo sapiens  Peroxisome proliferator-activated receptor gamma
#
#      target_tax_id text_value  toid  type units    uo_units upper_value  \
# 14            9606       None  None  IC50     M  UO_0000065        None
# 15            9606       None  None  IC50     M  UO_0000065        None
# 16            9606       None  None  IC50     M  UO_0000065        None
# 17            9606       None  None  IC50     M  UO_0000065        None
# 18            9606       None  None  IC50     M  UO_0000065        None
# ...            ...        ...   ...   ...   ...         ...         ...
# 1905          9606       None  None  IC50     M  UO_0000065        None
# 1906          9606       None  None  IC50     M  UO_0000065        None
# 1907          9606       None  None  IC50     M  UO_0000065        None
# 1908          9606       None  None  IC50     M  UO_0000065        None
# 1909          9606       None  None  IC50     M  UO_0000065        None
#
#              value
# 14    5.000000e-08
# 15    4.900000e-06
# 16    1.700000e-06
# 17    5.500000e-07
# 18    6.500000e-06
# ...            ...
# 1905  2.310000e-05
# 1906  5.660000e-07
# 1907  3.500000e-06
# 1908  5.300000e-06
# 1909  1.800000e-08
#
# [1714 rows x 46 columns]

# %%
## Assigning the class of compounds: active if IC50 < 1000 nM, inactive if IC50 > 10000 nM, and intermediate if IC50 is between 1000 nM and 100000 nM.
## The variable of interest is always "standard_value".

bioactivity_class = []
for i in df_assays_f_only.standard_value:
    if float(i) >= 10000:
        bioactivity_class.append("Inactive")
    elif float(i) < 1000:
        bioactivity_class.append("Active")
    else:
        bioactivity_class.append("Intermediate")

# %%
# Viewing the bioactive compounds
df_assays_f_only.molecule_chembl_id
# Out:
# 14       CHEMBL320553
# 15       CHEMBL149676
# 16       CHEMBL344282
# 17       CHEMBL278590
# 18       CHEMBL424133
#             ...
# 1905        CHEMBL150
# 1906      CHEMBL13045
# 1907     CHEMBL379064
# 1908    CHEMBL5290209
# 1909    CHEMBL3585580
# Name: molecule_chembl_id, Length: 1714, dtype: object

# %%
## 7.1. Iterating through the bioactive compounds:
mol_cid = []
for i in df_assays_f_only.molecule_chembl_id:
    mol_cid.append(i)

# %%
# Printing the variable mol_cid:
mol_cid
# Out:
# ['CHEMBL320553',
#  'CHEMBL149676',
#  'CHEMBL344282',
#  'CHEMBL278590',
#  'CHEMBL424133',
#  'CHEMBL147086',
#  'CHEMBL345721',
#  'CHEMBL148774',
#  'CHEMBL148639',
#  'CHEMBL356170',
#  'CHEMBL149438',
#  'CHEMBL24458',
#  'CHEMBL408',
#  'CHEMBL25259',
#  'CHEMBL294807',
#  'CHEMBL59132',
#  'CHEMBL65458',
#  'CHEMBL64972',
#  'CHEMBL66206',
#  'CHEMBL121',
#  'CHEMBL23874',
#  'CHEMBL23296',
#  'CHEMBL23670',
#  'CHEMBL279053',
#  'CHEMBL278994',
#  'CHEMBL121',
#  'CHEMBL23881',
#  'CHEMBL25710',
#  'CHEMBL180504',
#  'CHEMBL181644',
#  'CHEMBL181656',
#  'CHEMBL182230',
#  'CHEMBL121',
#  'CHEMBL981',
#  'CHEMBL182884',
#  'CHEMBL181954',
#  'CHEMBL363532',
#  'CHEMBL360368',
#  'CHEMBL192691',
#  'CHEMBL373142',
#  'CHEMBL370747',
#  'CHEMBL365387',
#  'CHEMBL192646',
#  'CHEMBL370074',
#  'CHEMBL363805',
#  'CHEMBL192919',
#  'CHEMBL365315',
#  'CHEMBL371341',
#  'CHEMBL179330',
#  'CHEMBL364894',
#  'CHEMBL191087',
#  'CHEMBL372913',
#  'CHEMBL195367',
#  'CHEMBL121',
#  'CHEMBL66206',
#  'CHEMBL81592',
#  'CHEMBL82034',
#  'CHEMBL199225',
#  'CHEMBL206794',
#  'CHEMBL204057',
#  'CHEMBL1783064',
#  'CHEMBL202739',
#  'CHEMBL424685',
#  'CHEMBL206202',
#  'CHEMBL205665',
#  'CHEMBL203621',
#  'CHEMBL383233',
#  'CHEMBL208472',
#  'CHEMBL378160',
#  'CHEMBL23296',
#  'CHEMBL427040',
#  'CHEMBL209563',
#  'CHEMBL207907',
#  'CHEMBL383728',
#  'CHEMBL207442',
#  'CHEMBL207103',
#  'CHEMBL207019',
#  'CHEMBL210973',
#  'CHEMBL210768',
#  'CHEMBL213314',
#  'CHEMBL121',
#  'CHEMBL215701',
#  'CHEMBL215245',
#  'CHEMBL213361',
#  'CHEMBL213315',
#  'CHEMBL214921',
#  'CHEMBL214026',
#  'CHEMBL377660',
#  'CHEMBL212591',
#  'CHEMBL212023',
#  'CHEMBL215127',
#  'CHEMBL215126',
#  'CHEMBL212911',
#  'CHEMBL378068',
#  'CHEMBL215582',
#  'CHEMBL376627',
#  'CHEMBL121',
#  'CHEMBL374657',
#  'CHEMBL385585',
#  'CHEMBL218230',
#  'CHEMBL218841',
#  'CHEMBL374705',
#  'CHEMBL218840',
#  'CHEMBL218789',
#  'CHEMBL218122',
#  'CHEMBL376051',
#  'CHEMBL435317',
#  'CHEMBL222165',
#  'CHEMBL436337',
#  'CHEMBL374363',
#  'CHEMBL386504',
#  'CHEMBL447538',
#  'CHEMBL386307',
#  'CHEMBL222026',
#  'CHEMBL220537',
#  'CHEMBL220475',
#  'CHEMBL221342',
#  'CHEMBL218176',
#  'CHEMBL218175',
#  'CHEMBL374189',
#  'CHEMBL221580',
#  'CHEMBL217962',
#  'CHEMBL218258',
#  'CHEMBL267881',
#  'CHEMBL218231',
#  'CHEMBL981',
#  'CHEMBL121',
#  'CHEMBL107367',
#  'CHEMBL408',
#  'CHEMBL220622',
#  'CHEMBL387373',
#  'CHEMBL446365',
#  'CHEMBL223434',
#  'CHEMBL219836',
#  'CHEMBL376460',
#  'CHEMBL441554',
#  'CHEMBL223351',
#  'CHEMBL374344',
#  'CHEMBL223350',
#  'CHEMBL223128',
#  'CHEMBL373685',
#  'CHEMBL220622',
#  'CHEMBL219824',
#  'CHEMBL219773',
#  'CHEMBL223349',
#  'CHEMBL223379',
#  'CHEMBL981',
#  'CHEMBL121',
#  'CHEMBL234659',
#  'CHEMBL234660',
#  'CHEMBL392950',
#  'CHEMBL234663',
#  'CHEMBL234662',
#  'CHEMBL232396',
#  'CHEMBL391479',
#  'CHEMBL232395',
#  'CHEMBL391478',
#  'CHEMBL233177',
#  'CHEMBL233978',
#  'CHEMBL231690',
#  'CHEMBL393373',
#  'CHEMBL231689',
#  'CHEMBL231688',
#  'CHEMBL393767',
#  'CHEMBL234801',
#  'CHEMBL234800',
#  'CHEMBL234799',
#  'CHEMBL393766',
#  'CHEMBL234589',
#  'CHEMBL234588',
#  'CHEMBL234587',
#  'CHEMBL234383',
#  'CHEMBL234382',
#  'CHEMBL391085',
#  'CHEMBL234169',
#  'CHEMBL391084',
#  'CHEMBL234168',
#  'CHEMBL391068',
#  'CHEMBL233976',
#  'CHEMBL392058',
#  'CHEMBL121',
#  'CHEMBL401236',
#  'CHEMBL238357',
#  'CHEMBL238152',
#  'CHEMBL235143',
#  'CHEMBL399417',
#  'CHEMBL399217',
#  'CHEMBL236218',
#  'CHEMBL237485',
#  'CHEMBL237484',
#  'CHEMBL237277',
#  'CHEMBL392718',
#  'CHEMBL237730',
#  'CHEMBL237520',
#  'CHEMBL392717',
#  'CHEMBL237519',
#  'CHEMBL237518',
#  'CHEMBL237307',
#  'CHEMBL393940',
#  'CHEMBL237306',
#  'CHEMBL237305',
#  'CHEMBL237086',
#  'CHEMBL393939',
#  'CHEMBL237085',
#  'CHEMBL237710',
#  'CHEMBL237084',
#  'CHEMBL236877',
#  'CHEMBL236876',
#  'CHEMBL393938',
#  'CHEMBL236875',
#  'CHEMBL236664',
#  'CHEMBL212911',
#  'CHEMBL121',
#  'CHEMBL238970',
#  'CHEMBL241479',
#  'CHEMBL241478',
#  'CHEMBL241299',
#  'CHEMBL391470',
#  'CHEMBL241298',
#  'CHEMBL400024',
#  'CHEMBL241286',
#  'CHEMBL391283',
#  'CHEMBL241472',
#  'CHEMBL241471',
#  'CHEMBL391264',
#  'CHEMBL241078',
#  'CHEMBL392063',
#  'CHEMBL393926',
#  'CHEMBL443343',
#  'CHEMBL469938',
#  'CHEMBL469939',
#  'CHEMBL467711',
#  'CHEMBL469940',
#  'CHEMBL451531',
#  'CHEMBL469941',
#  'CHEMBL471828',
#  'CHEMBL471829',
#  'CHEMBL471830',
#  'CHEMBL470574',
#  'CHEMBL513215',
#  'CHEMBL470575',
#  'CHEMBL452051',
#  'CHEMBL517436',
#  'CHEMBL461944',
#  'CHEMBL461379',
#  'CHEMBL518499',
#  'CHEMBL461378',
#  'CHEMBL459466',
#  'CHEMBL460073',
#  'CHEMBL460072',
#  'CHEMBL462378',
#  'CHEMBL509236',
#  'CHEMBL510180',
#  'CHEMBL455130',
#  'CHEMBL509369',
#  'CHEMBL452054',
#  'CHEMBL507477',
#  'CHEMBL455127',
#  'CHEMBL455126',
#  'CHEMBL452299',
#  'CHEMBL179330',
#  'CHEMBL363805',
#  'CHEMBL489651',
#  'CHEMBL519060',
#  'CHEMBL522772',
#  'CHEMBL121',
#  'CHEMBL490029',
#  'CHEMBL672',
#  'CHEMBL121',
#  'CHEMBL560830',
#  'CHEMBL558083',
#  'CHEMBL558083',
#  'CHEMBL562864',
#  'CHEMBL564902',
#  'CHEMBL564036',
#  'CHEMBL560160',
#  'CHEMBL552240',
#  'CHEMBL549746',
#  'CHEMBL461571',
#  'CHEMBL452051',
#  'CHEMBL559567',
#  'CHEMBL556073',
#  'CHEMBL1089176',
#  'CHEMBL1088910',
#  'CHEMBL1088911',
#  'CHEMBL1089210',
#  'CHEMBL1090211',
#  'CHEMBL1090212',
#  'CHEMBL1091664',
#  'CHEMBL1091980',
#  'CHEMBL1092931',
#  'CHEMBL1089164',
#  'CHEMBL1090187',
#  'CHEMBL1089969',
#  'CHEMBL1089970',
#  'CHEMBL1090188',
#  'CHEMBL1090189',
#  'CHEMBL1090877',
#  'CHEMBL1090878',
#  'CHEMBL1091218',
#  'CHEMBL1092235',
#  'CHEMBL1092236',
#  'CHEMBL1092237',
#  'CHEMBL1091196',
#  'CHEMBL1089500',
#  'CHEMBL1089501',
#  'CHEMBL1093405',
#  'CHEMBL1090443',
#  'CHEMBL121',
#  'CHEMBL1629930',
#  'CHEMBL378160',
#  'CHEMBL595',
#  'CHEMBL121',
#  'CHEMBL1933845',
#  'CHEMBL1933842',
#  'CHEMBL1933841',
#  'CHEMBL1933822',
#  'CHEMBL1946566',
#  'CHEMBL1946567',
#  'CHEMBL1946568',
#  'CHEMBL1946569',
#  'CHEMBL1946570',
#  'CHEMBL1946571',
#  'CHEMBL1946572',
#  'CHEMBL1946753',
#  'CHEMBL1946754',
#  'CHEMBL1946755',
#  'CHEMBL1946756',
#  'CHEMBL1946757',
#  'CHEMBL1946758',
#  'CHEMBL1946952',
#  'CHEMBL1946953',
#  'CHEMBL1946954',
#  'CHEMBL1946955',
#  'CHEMBL1947138',
#  'CHEMBL1947139',
#  'CHEMBL1947140',
#  'CHEMBL1947141',
#  'CHEMBL1947142',
#  'CHEMBL1947143',
#  'CHEMBL1947144',
#  'CHEMBL1947145',
#  'CHEMBL1947146',
#  'CHEMBL1947147',
#  'CHEMBL2024606',
#  'CHEMBL2331784',
#  'CHEMBL121',
#  'CHEMBL121',
#  'CHEMBL3425797',
#  'CHEMBL1551302',
#  'CHEMBL458053',
#  'CHEMBL595',
#  'CHEMBL408',
#  'CHEMBL602468',
#  'CHEMBL602469',
#  'CHEMBL3695841',
#  'CHEMBL3695829',
#  'CHEMBL3695852',
#  'CHEMBL3695839',
#  'CHEMBL3695837',
#  'CHEMBL3695843',
#  'CHEMBL3695840',
#  'CHEMBL3695771',
#  'CHEMBL3695831',
#  'CHEMBL3695772',
#  'CHEMBL3695821',
#  'CHEMBL3695813',
#  'CHEMBL3695826',
#  'CHEMBL3695819',
#  'CHEMBL1230353',
#  'CHEMBL3695832',
#  'CHEMBL3695845',
#  'CHEMBL3695846',
#  'CHEMBL3695776',
#  'CHEMBL3695780',
#  'CHEMBL3348830',
#  'CHEMBL3695811',
#  'CHEMBL3695760',
#  'CHEMBL3695765',
#  'CHEMBL3699396',
#  'CHEMBL3699399',
#  'CHEMBL3699398',
#  'CHEMBL3699401',
#  'CHEMBL3735987',
#  'CHEMBL3735765',
#  'CHEMBL3736229',
#  'CHEMBL3699424',
#  'CHEMBL3735906',
#  'CHEMBL3735470',
#  'CHEMBL3699397',
#  'CHEMBL3735674',
#  'CHEMBL3735924',
#  'CHEMBL3736075',
#  'CHEMBL3735503',
#  'CHEMBL3736263',
#  'CHEMBL3695916',
#  'CHEMBL3734773',
#  'CHEMBL3736463',
#  'CHEMBL3736501',
#  'CHEMBL3736374',
#  'CHEMBL3736412',
#  'CHEMBL121',
#  'CHEMBL3780740',
#  'CHEMBL3827820',
#  'CHEMBL3828232',
#  'CHEMBL3827335',
#  'CHEMBL3828718',
#  'CHEMBL3695760',
#  'CHEMBL3695761',
#  'CHEMBL3695762',
#  'CHEMBL3695763',
#  'CHEMBL3695764',
#  'CHEMBL3695765',
#  'CHEMBL3695766',
#  'CHEMBL3695767',
#  'CHEMBL3695768',
#  'CHEMBL3695769',
#  'CHEMBL3695770',
#  'CHEMBL3695771',
#  'CHEMBL3695772',
#  'CHEMBL3695773',
#  'CHEMBL3695774',
#  'CHEMBL3695775',
#  'CHEMBL3695776',
#  'CHEMBL3695777',
#  'CHEMBL3695778',
#  'CHEMBL3695779',
#  'CHEMBL3695780',
#  'CHEMBL3695781',
#  'CHEMBL3695782',
#  'CHEMBL3695783',
#  'CHEMBL3695784',
#  'CHEMBL3695785',
#  'CHEMBL3695786',
#  'CHEMBL3695787',
#  'CHEMBL3695788',
#  'CHEMBL3695789',
#  'CHEMBL3695790',
#  'CHEMBL3695791',
#  'CHEMBL3695792',
#  'CHEMBL3695793',
#  'CHEMBL3695794',
#  'CHEMBL3695795',
#  'CHEMBL3695796',
#  'CHEMBL3695797',
#  'CHEMBL3695798',
#  'CHEMBL3695799',
#  'CHEMBL3695800',
#  'CHEMBL3695801',
#  'CHEMBL3695802',
#  'CHEMBL3695803',
#  'CHEMBL3695804',
#  'CHEMBL3695805',
#  'CHEMBL3695806',
#  'CHEMBL3695807',
#  'CHEMBL3695808',
#  'CHEMBL3695809',
#  'CHEMBL3695810',
#  'CHEMBL3695811',
#  'CHEMBL3348830',
#  'CHEMBL3695812',
#  'CHEMBL3695813',
#  'CHEMBL3695814',
#  'CHEMBL3695815',
#  'CHEMBL3695816',
#  'CHEMBL3695817',
#  'CHEMBL3695818',
#  'CHEMBL3695819',
#  'CHEMBL3695820',
#  'CHEMBL3695821',
#  'CHEMBL3695822',
#  'CHEMBL3695823',
#  'CHEMBL3699442',
#  'CHEMBL3695824',
#  'CHEMBL3695825',
#  'CHEMBL3695826',
#  'CHEMBL3695827',
#  'CHEMBL3695828',
#  'CHEMBL602469',
#  'CHEMBL3695829',
#  'CHEMBL3695830',
#  'CHEMBL3695831',
#  'CHEMBL3695832',
#  'CHEMBL1230353',
#  'CHEMBL3695833',
#  'CHEMBL3695834',
#  'CHEMBL3695835',
#  'CHEMBL3695836',
#  'CHEMBL3695837',
#  'CHEMBL3695838',
#  'CHEMBL3695839',
#  'CHEMBL3695840',
#  'CHEMBL3695841',
#  'CHEMBL3695842',
#  'CHEMBL3639947',
#  'CHEMBL3695843',
#  'CHEMBL3695844',
#  'CHEMBL3695845',
#  'CHEMBL3695846',
#  'CHEMBL3695847',
#  'CHEMBL3695848',
#  'CHEMBL3695849',
#  'CHEMBL3695850',
#  'CHEMBL3695851',
#  'CHEMBL3695852',
#  'CHEMBL3695853',
#  'CHEMBL3695854',
#  'CHEMBL3695855',
#  'CHEMBL3695856',
#  'CHEMBL3695857',
#  'CHEMBL3695858',
#  'CHEMBL3695859',
#  'CHEMBL602263',
#  'CHEMBL3695860',
#  'CHEMBL3695861',
#  'CHEMBL3695862',
#  'CHEMBL3695863',
#  'CHEMBL3695864',
#  'CHEMBL3695865',
#  'CHEMBL3695866',
#  'CHEMBL3695867',
#  'CHEMBL3695868',
#  'CHEMBL3695869',
#  'CHEMBL3695870',
#  'CHEMBL3695871',
#  'CHEMBL3695872',
#  'CHEMBL3695873',
#  'CHEMBL3695874',
#  'CHEMBL3695875',
#  'CHEMBL3695876',
#  'CHEMBL3695877',
#  'CHEMBL3695878',
#  'CHEMBL3695879',
#  'CHEMBL3695880',
#  'CHEMBL3695881',
#  'CHEMBL3695882',
#  'CHEMBL3695883',
#  'CHEMBL3695884',
#  'CHEMBL3695885',
#  'CHEMBL3695886',
#  'CHEMBL3695887',
#  'CHEMBL3695888',
#  'CHEMBL3695889',
#  'CHEMBL3695890',
#  'CHEMBL3695891',
#  'CHEMBL3695892',
#  'CHEMBL3695893',
#  'CHEMBL3695894',
#  'CHEMBL3695895',
#  'CHEMBL3695896',
#  'CHEMBL3695897',
#  'CHEMBL3695898',
#  'CHEMBL3695899',
#  'CHEMBL3695900',
#  'CHEMBL3695901',
#  'CHEMBL3695902',
#  'CHEMBL3695903',
#  'CHEMBL3695904',
#  'CHEMBL3695905',
#  'CHEMBL3695906',
#  'CHEMBL3695907',
#  'CHEMBL3695908',
#  'CHEMBL3695909',
#  'CHEMBL3695910',
#  'CHEMBL3695911',
#  'CHEMBL3695912',
#  'CHEMBL3695913',
#  'CHEMBL3695914',
#  'CHEMBL3695915',
#  'CHEMBL3695916',
#  'CHEMBL3699345',
#  'CHEMBL3699346',
#  'CHEMBL3699347',
#  'CHEMBL3699348',
#  'CHEMBL3699349',
#  'CHEMBL3699350',
#  'CHEMBL3699351',
#  'CHEMBL3699352',
#  'CHEMBL3699353',
#  'CHEMBL3699354',
#  'CHEMBL3699355',
#  'CHEMBL3699356',
#  'CHEMBL3699357',
#  'CHEMBL3699358',
#  'CHEMBL3699359',
#  'CHEMBL3699360',
#  'CHEMBL3699361',
#  'CHEMBL3699362',
#  'CHEMBL3699363',
#  'CHEMBL3699364',
#  'CHEMBL3699365',
#  'CHEMBL3699366',
#  'CHEMBL3699367',
#  'CHEMBL3699368',
#  'CHEMBL3699369',
#  'CHEMBL3699370',
#  'CHEMBL3699371',
#  'CHEMBL3699372',
#  'CHEMBL3699373',
#  'CHEMBL3699374',
#  'CHEMBL3699375',
#  'CHEMBL3699376',
#  'CHEMBL3699377',
#  'CHEMBL3699378',
#  'CHEMBL3699379',
#  'CHEMBL3699380',
#  'CHEMBL3699381',
#  'CHEMBL3699382',
#  'CHEMBL3699383',
#  'CHEMBL3699384',
#  'CHEMBL3699385',
#  'CHEMBL3699386',
#  'CHEMBL3699387',
#  'CHEMBL3699388',
#  'CHEMBL3699389',
#  'CHEMBL3699390',
#  'CHEMBL3699391',
#  'CHEMBL3699392',
#  'CHEMBL3699393',
#  'CHEMBL3699442',
#  'CHEMBL3699394',
#  'CHEMBL3699395',
#  'CHEMBL3699396',
#  'CHEMBL3699397',
#  'CHEMBL3699398',
#  'CHEMBL3699399',
#  'CHEMBL3699400',
#  'CHEMBL3699401',
#  'CHEMBL3699402',
#  'CHEMBL3699403',
#  'CHEMBL3699404',
#  'CHEMBL3699405',
#  'CHEMBL3699406',
#  'CHEMBL3639982',
#  'CHEMBL3699407',
#  'CHEMBL3699408',
#  'CHEMBL3699409',
#  'CHEMBL3699410',
#  'CHEMBL3699411',
#  'CHEMBL3699412',
#  'CHEMBL3699413',
#  'CHEMBL3699414',
#  'CHEMBL3699415',
#  'CHEMBL3699416',
#  'CHEMBL3699417',
#  'CHEMBL3699418',
#  'CHEMBL3699419',
#  'CHEMBL3699420',
#  'CHEMBL3699421',
#  'CHEMBL3699422',
#  'CHEMBL3699423',
#  'CHEMBL3699424',
#  'CHEMBL3699425',
#  'CHEMBL3699426',
#  'CHEMBL3699427',
#  'CHEMBL3699428',
#  'CHEMBL3699429',
#  'CHEMBL3699430',
#  'CHEMBL3699431',
#  'CHEMBL3699432',
#  'CHEMBL3699433',
#  'CHEMBL3699434',
#  'CHEMBL3699435',
#  'CHEMBL3699436',
#  'CHEMBL3699437',
#  'CHEMBL3699438',
#  'CHEMBL3699439',
#  'CHEMBL3699440',
#  'CHEMBL3699441',
#  'CHEMBL3678080',
#  'CHEMBL3678081',
#  'CHEMBL3678082',
#  'CHEMBL3678083',
#  'CHEMBL3678084',
#  'CHEMBL3678085',
#  'CHEMBL3678086',
#  'CHEMBL3678087',
#  'CHEMBL3678088',
#  'CHEMBL3678089',
#  'CHEMBL3678090',
#  'CHEMBL3678091',
#  'CHEMBL3678092',
#  'CHEMBL3678093',
#  'CHEMBL3678094',
#  'CHEMBL3678095',
#  'CHEMBL3678096',
#  'CHEMBL3678097',
#  'CHEMBL3678098',
#  'CHEMBL3678099',
#  'CHEMBL3678100',
#  'CHEMBL3678101',
#  'CHEMBL3678102',
#  'CHEMBL3678103',
#  'CHEMBL3678104',
#  'CHEMBL3678105',
#  'CHEMBL3678106',
#  'CHEMBL3678107',
#  'CHEMBL3678108',
#  'CHEMBL3678109',
#  'CHEMBL3678110',
#  'CHEMBL3678111',
#  'CHEMBL3678112',
#  'CHEMBL3678113',
#  'CHEMBL3678114',
#  'CHEMBL3678115',
#  'CHEMBL3678116',
#  'CHEMBL3678117',
#  'CHEMBL3678118',
#  'CHEMBL3678119',
#  'CHEMBL3678120',
#  'CHEMBL3678121',
#  'CHEMBL3639769',
#  'CHEMBL3678122',
#  'CHEMBL3678123',
#  'CHEMBL3678124',
#  'CHEMBL3678125',
#  'CHEMBL3678126',
#  'CHEMBL3678127',
#  'CHEMBL3678128',
#  'CHEMBL3678129',
#  'CHEMBL3678130',
#  'CHEMBL3678131',
#  'CHEMBL3678132',
#  'CHEMBL3678133',
#  'CHEMBL3678134',
#  'CHEMBL3678135',
#  'CHEMBL3678136',
#  'CHEMBL3678137',
#  'CHEMBL3678138',
#  'CHEMBL3678139',
#  'CHEMBL3678140',
#  'CHEMBL3678141',
#  'CHEMBL3678142',
#  'CHEMBL3678143',
#  'CHEMBL3678144',
#  'CHEMBL3678128',
#  'CHEMBL3678134',
#  'CHEMBL3678117',
#  'CHEMBL3678145',
#  'CHEMBL3678146',
#  'CHEMBL3678146',
#  'CHEMBL3678147',
#  'CHEMBL3678148',
#  'CHEMBL3678149',
#  'CHEMBL3678150',
#  'CHEMBL3678151',
#  'CHEMBL3678152',
#  'CHEMBL3678153',
#  'CHEMBL3678154',
#  'CHEMBL3678155',
#  'CHEMBL3678156',
#  'CHEMBL3678157',
#  'CHEMBL3678158',
#  'CHEMBL3678159',
#  'CHEMBL3678160',
#  'CHEMBL3678161',
#  'CHEMBL3678162',
#  'CHEMBL3678163',
#  'CHEMBL186179',
#  'CHEMBL13045',
#  'CHEMBL121',
#  'CHEMBL4743677',
#  'CHEMBL121',
#  'CHEMBL4743677',
#  'CHEMBL4802042',
#  'CHEMBL121',
#  'CHEMBL3348830',
#  'CHEMBL5070753',
#  'CHEMBL121',
#  'CHEMBL3348830',
#  'CHEMBL5070753',
#  'CHEMBL5186962',
#  'CHEMBL5201306',
#  'CHEMBL5207130',
#  'CHEMBL5174641',
#  'CHEMBL2324298',
#  'CHEMBL5179281',
#  'CHEMBL5191837',
#  'CHEMBL5206512',
#  'CHEMBL5182665',
#  'CHEMBL5199152',
#  'CHEMBL5183657',
#  'CHEMBL5201278',
#  'CHEMBL5204936',
#  'CHEMBL5169731',
#  'CHEMBL5184027',
#  'CHEMBL5170260',
#  'CHEMBL5200843',
#  'CHEMBL5203129',
#  'CHEMBL5171685',
#  'CHEMBL5173312',
#  'CHEMBL2447934',
#  'CHEMBL5201597',
#  'CHEMBL5172001',
#  'CHEMBL5179111',
#  'CHEMBL5206276',
#  'CHEMBL5187164',
#  'CHEMBL5207464',
#  'CHEMBL5207130',
#  'CHEMBL5187164',
#  'CHEMBL3598140',
#  'CHEMBL5284640',
#  'CHEMBL5278668',
#  'CHEMBL5286808',
#  'CHEMBL5283176',
#  'CHEMBL5273188',
#  'CHEMBL5289955',
#  'CHEMBL5287868',
#  'CHEMBL5272116',
#  'CHEMBL5281604',
#  'CHEMBL5282181',
#  'CHEMBL5268912',
#  'CHEMBL5287514',
#  'CHEMBL5288593',
#  'CHEMBL5287866',
#  'CHEMBL5282748',
#  'CHEMBL5273751',
#  'CHEMBL5291018',
#  'CHEMBL5285688',
#  'CHEMBL5277957',
#  'CHEMBL5281842',
#  'CHEMBL5286386',
#  'CHEMBL5267263',
#  'CHEMBL5272194',
#  'CHEMBL5273393',
#  'CHEMBL5282503',
#  'CHEMBL5271038',
#  'CHEMBL5286386',
#  'CHEMBL5267263',
#  'CHEMBL5271038',
#  'CHEMBL510698',
#  'CHEMBL3678128',
#  'CHEMBL1236924',
#  'CHEMBL327767',
#  'CHEMBL94496',
#  'CHEMBL420441',
#  'CHEMBL121',
#  'CHEMBL330191',
#  'CHEMBL300629',
#  'CHEMBL328615',
#  'CHEMBL96107',
#  'CHEMBL94397',
#  'CHEMBL97529',
#  'CHEMBL96758',
#  'CHEMBL96143',
#  'CHEMBL94716',
#  'CHEMBL96451',
#  'CHEMBL92130',
#  'CHEMBL318684',
#  'CHEMBL94306',
#  'CHEMBL54097',
#  'CHEMBL52426',
#  'CHEMBL51603',
#  'CHEMBL430970',
#  'CHEMBL50885',
#  'CHEMBL298187',
#  'CHEMBL50755',
#  'CHEMBL50984',
#  'CHEMBL50572',
#  'CHEMBL300629',
#  'CHEMBL50143',
#  'CHEMBL53688',
#  'CHEMBL53746',
#  'CHEMBL50680',
#  'CHEMBL54197',
#  'CHEMBL52633',
#  'CHEMBL300026',
#  'CHEMBL50259',
#  'CHEMBL301156',
#  'CHEMBL121',
#  'CHEMBL122417',
#  'CHEMBL117738',
#  'CHEMBL119066',
#  'CHEMBL116774',
#  'CHEMBL120570',
#  'CHEMBL94306',
#  'CHEMBL118753',
#  'CHEMBL418874',
#  'CHEMBL118169',
#  'CHEMBL280293',
#  'CHEMBL117578',
#  'CHEMBL419768',
#  'CHEMBL118251',
#  'CHEMBL117918',
#  'CHEMBL118756',
#  'CHEMBL119496',
#  'CHEMBL331071',
#  'CHEMBL121106',
#  'CHEMBL121106',
#  'CHEMBL333304',
#  'CHEMBL333304',
#  'CHEMBL122418',
#  'CHEMBL117165',
#  'CHEMBL332018',
#  'CHEMBL115604',
#  'CHEMBL107789',
#  'CHEMBL112790',
#  'CHEMBL111271',
#  'CHEMBL107991',
#  'CHEMBL111161',
#  'CHEMBL431450',
#  'CHEMBL109773',
#  'CHEMBL121',
#  'CHEMBL324449',
#  'CHEMBL112973',
#  'CHEMBL282686',
#  'CHEMBL110071',
#  'CHEMBL110743',
#  'CHEMBL109975',
#  'CHEMBL109638',
#  'CHEMBL111480',
#  'CHEMBL109731',
#  'CHEMBL323008',
#  'CHEMBL419756',
#  'CHEMBL113324',
#  'CHEMBL112725',
#  'CHEMBL595',
#  'CHEMBL24038',
#  'CHEMBL326273',
#  'CHEMBL326873',
#  'CHEMBL24683',
#  'CHEMBL419019',
#  'CHEMBL109241',
#  'CHEMBL114286',
#  'CHEMBL121',
#  'CHEMBL179622',
#  'CHEMBL176075',
#  'CHEMBL435343',
#  'CHEMBL361166',
#  'CHEMBL361424',
#  'CHEMBL424957',
#  'CHEMBL180123',
#  'CHEMBL179657',
#  'CHEMBL176222',
#  'CHEMBL367549',
#  'CHEMBL179180',
#  'CHEMBL447190',
#  'CHEMBL360919',
#  'CHEMBL360992',
#  'CHEMBL360240',
#  'CHEMBL369289',
#  'CHEMBL360231',
#  'CHEMBL178659',
#  'CHEMBL426592',
#  'CHEMBL178309',
#  'CHEMBL180019',
#  'CHEMBL359476',
#  'CHEMBL181835',
#  'CHEMBL179604',
#  'CHEMBL181141',
#  'CHEMBL360762',
#  'CHEMBL181628',
#  'CHEMBL182100',
#  'CHEMBL181937',
#  'CHEMBL179542',
#  'CHEMBL361395',
#  'CHEMBL435517',
#  'CHEMBL179330',
#  'CHEMBL359548',
#  'CHEMBL178236',
#  'CHEMBL367891',
#  'CHEMBL445921',
#  'CHEMBL181554',
#  'CHEMBL179452',
#  'CHEMBL178513',
#  'CHEMBL178630',
#  'CHEMBL178909',
#  'CHEMBL360246',
#  'CHEMBL112725',
#  'CHEMBL369725',
#  'CHEMBL180912',
#  'CHEMBL182200',
#  'CHEMBL181219',
#  'CHEMBL178321',
#  'CHEMBL181087',
#  'CHEMBL178245',
#  'CHEMBL178562',
#  'CHEMBL367360',
#  'CHEMBL180928',
#  'CHEMBL361427',
#  'CHEMBL190938',
#  'CHEMBL371832',
#  'CHEMBL187612',
#  'CHEMBL190517',
#  'CHEMBL364378',
#  'CHEMBL192636',
#  'CHEMBL193082',
#  'CHEMBL364274',
#  'CHEMBL192521',
#  'CHEMBL372220',
#  'CHEMBL188095',
#  'CHEMBL371778',
#  'CHEMBL427530',
#  'CHEMBL191149',
#  'CHEMBL191556',
#  'CHEMBL190169',
#  'CHEMBL365097',
#  'CHEMBL364467',
#  'CHEMBL371195',
#  'CHEMBL191235',
#  ...]

# %%
## 7.2. Iterating over canonical SMILES into a list.
canonical_smiles = []
for i in df_assays.canonical_smiles:
    canonical_smiles.append(i)

# %%
## 7.3. Iterating over standard_value into a list.
standard_value = []
for i in df_assays.standard_value:
    standard_value.append(i)

# %%
## 7.4. Combining the four variables into the same DataFrame.
dados_tupla = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( dados_tupla,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL320553  Cc1oc(-c2ccccc2)nc1CCOc1ccc(C[C@](C)(Oc2ccccc2...
# 1          CHEMBL149676  Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC(C)(Oc2ccccc2)C(...
# 2          CHEMBL344282  Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC(Oc2ccccc2)C(=O)...
# 3          CHEMBL278590  Cc1oc(C2CCCCC2)nc1CCOc1ccc(C[C@](C)(Oc2ccccc2)...
# 4          CHEMBL424133  Cc1oc(-c2cccs2)nc1CCOc1ccc(C[C@](C)(Oc2ccccc2)...
# ...                 ...                                                ...
# 1709          CHEMBL150        CCN(CCOc1ccc(/C=C2\SC(=O)NC2=O)cc1)c1ccccn1
# 1710        CHEMBL13045       CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1nc2ccccc2s1
# 1711       CHEMBL379064    CN(CCOc1ccc(/C=C2\SC(=O)NC2=O)cc1)c1nc2ccccc2s1
# 1712      CHEMBL5290209      CCN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1nc2ccccc2s1
# 1713      CHEMBL3585580   CCN(CCOc1ccc(/C=C2\SC(=O)NC2=O)cc1)c1nc2ccccc2s1
#
#      bioactivity_class standard_value
# 0               Active           14.0
# 1         Intermediate           18.0
# 2         Intermediate          128.0
# 3               Active           15.0
# 4         Intermediate           10.0
# ...                ...            ...
# 1709          Inactive        15000.0
# 1710            Active        20000.0
# 1711      Intermediate        13000.0
# 1712      Intermediate        25000.0
# 1713            Active        17000.0
#
# [1714 rows x 4 columns]

# %%
# Saving the DataFrame to a CSV file.

df3.to_csv('Peroxisome proliferator-activated receptor gamma.csv', index=False)

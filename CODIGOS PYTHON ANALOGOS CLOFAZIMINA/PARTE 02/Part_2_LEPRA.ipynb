# %%
# Step 2: Import dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2d733bd0-ab99-491d-b97f-c50393a9541d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2d733bd0-ab99-491d-b97f-c50393a9541d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Step 2: Reading the dataset.
import pandas as pd
df1 = pd.read_csv("Peroxisome proliferator-activated receptor gamma.csv")
df1
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL320553  Cc1oc(-c2ccccc2)nc1CCOc1ccc(C[C@](C)(Oc2ccccc2...
# 1          CHEMBL149676  Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC(C)(Oc2ccccc2)C(...
# 2          CHEMBL344282  Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC(Oc2ccccc2)C(=O)...
# 3          CHEMBL278590  Cc1oc(C2CCCCC2)nc1CCOc1ccc(C[C@](C)(Oc2ccccc2)...
# 4          CHEMBL424133  Cc1oc(-c2cccs2)nc1CCOc1ccc(C[C@](C)(Oc2ccccc2)...
# ...                 ...                                                ...
# 1709          CHEMBL150        CCN(CCOc1ccc(/C=C2\SC(=O)NC2=O)cc1)c1ccccn1
# 1710        CHEMBL13045       CN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1nc2ccccc2s1
# 1711       CHEMBL379064    CN(CCOc1ccc(/C=C2\SC(=O)NC2=O)cc1)c1nc2ccccc2s1
# 1712      CHEMBL5290209      CCN(CCOc1ccc(CC2SC(=O)NC2=O)cc1)c1nc2ccccc2s1
# 1713      CHEMBL3585580   CCN(CCOc1ccc(/C=C2\SC(=O)NC2=O)cc1)c1nc2ccccc2s1
#
#      bioactivity_class  standard_value
# ...

# %%
# Step 2: Import dataset from 2000
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d873df48-44ed-4d0f-90f4-46e75743bd60" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d873df48-44ed-4d0f-90f4-46e75743bd60">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Step 2: Reading the dataset Voltage-gated potassium channel subunit Kv1.3
df2 = pd.read_csv ("Voltage-gated potassium channel subunit Kv1.3 F.csv")
display (df2.head())
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL55791  C=C(C)O[C@H]1[C@@H](OC(C)=O)[C@H]2[C@@](C)(CC[...
# 1        CHEMBL56173  CCCCCCNc1cc[n+](-c2ccccc2)c2c(-c3ccccc3)cc(OC)...
# 2        CHEMBL53676            CCCC/N=c1\ccn(CCCc2ccccc2)c2cc(Cl)ccc12
# 3       CHEMBL298622                   CCCCCCOc1ccc(Cc2ccccc2)c2ccccc12
# 4        CHEMBL56589        O=C(O)CC/N=c1\ccn(Cc2ccccc2Cl)c2cc(Cl)ccc12
#
#   bioactivity_class  standard_value
# 0      Intermediate            86.0
# 1      Intermediate           240.0
# 2            Active           471.0
# 3            Active          5000.0
# 4            Active         10000.0

# %%
# Combine the DataFrames vertically
df_combined = pd.concat([df1, df2], ignore_index=True)

# %%
df_combined = df_combined.dropna(subset=['canonical_smiles'])

# %%
df_combined
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL320553  Cc1oc(-c2ccccc2)nc1CCOc1ccc(C[C@](C)(Oc2ccccc2...
# 1          CHEMBL149676  Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC(C)(Oc2ccccc2)C(...
# 2          CHEMBL344282  Cc1oc(-c2ccccc2)nc1CCOc1ccc(CC(Oc2ccccc2)C(=O)...
# 3          CHEMBL278590  Cc1oc(C2CCCCC2)nc1CCOc1ccc(C[C@](C)(Oc2ccccc2)...
# 4          CHEMBL424133  Cc1oc(-c2cccs2)nc1CCOc1ccc(C[C@](C)(Oc2ccccc2)...
# ...                 ...                                                ...
# 1892       CHEMBL278501  COc1ccccc1CCC1(O)C(C)=C[C@@H](OC(C)=O)[C@@]2(C...
# 1893       CHEMBL265334  CCOc1ccccc1CCC1(O)C(C)=C[C@@H](OC(C)=O)[C@@]2(...
# 1894        CHEMBL16428  CCOc1ccccc1CCC1(O)C(C)=C[C@@H](OC(C)=O)[C@@]2(...
# 1895       CHEMBL360583  COc1cccc(CCC2(O)C(C)=C[C@@H](OC(C)=O)[C@@]3(C)...
# 1896       CHEMBL516932  COc1cccc(CCC2(O)C(C)=C[C@@H](OC(C)=O)[C@@]3(C)...
#
#      bioactivity_class  standard_value
# ...

# %%
# Step 5: Downloading the combined datasets
df_combined.to_csv('Lepra Clofazimina_PART02 F.csv', index=False)
